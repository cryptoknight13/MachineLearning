# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Robot-class" data-toc-modified-id="Robot-class-1"><span class="toc-item-num">1&nbsp;&nbsp;</span><code>Robot</code> class</a></span></li><li><span><a href="#Reinforcement-Learning-Problem-for-Controlling-the-Robot" data-toc-modified-id="Reinforcement-Learning-Problem-for-Controlling-the-Robot-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Reinforcement Learning Problem for Controlling the Robot</a></span></li><li><span><a href="#Reinforcement-Learning-Training-Algorithm" data-toc-modified-id="Reinforcement-Learning-Training-Algorithm-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Reinforcement Learning Training Algorithm</a></span></li><li><span><a href="#Required-Experiments" data-toc-modified-id="Required-Experiments-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Required Experiments</a></span><ul class="toc-item"><li><span><a href="#Good-parameter-values" data-toc-modified-id="Good-parameter-values-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Good parameter values</a></span></li><li><span><a href="#Create-robot-with-four-links-of-lengths,-4,-3,-3,--and-2." data-toc-modified-id="Create-robot-with-four-links-of-lengths,-4,-3,-3,--and-2.-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Create robot with four links of lengths, 4, 3, 3,  and 2.</a></span></li><li><span><a href="#Increase-number-of-valid-actions" data-toc-modified-id="Increase-number-of-valid-actions-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Increase number of valid actions</a></span></li></ul></li><li><span><a href="#Extra-Credit" data-toc-modified-id="Extra-Credit-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Extra Credit</a></span></li></ul></div>

# %% [markdown]
# <font size=5>A6 Reinforcement Learning to Control a Robot</font>

# %% [markdown]
# In this assignment, you will play with a simulation of a two-dimensional robot arm with multiple links and joints. You will train a neural network to approximate the Q function.
#
# The state of the arm is just the angles of each joint.  To remove the huge difference between joint angles of 359 degrees and 1 degree as a joint moves, we will represent each joint angle with two values, the sine and cosine of the angle, as the state input to the neural network. Valid actions on each step will be $-0.1$, $0$, and $+0.1$ applied to each joint.

# %% [markdown]
# # `Robot` class

# %% [markdown]
# Here is an implementation of the robot simulation.

# %%
import numpy as np
import copy
import matplotlib.pyplot as plt
import sys
import itertools  # for product (cross product)
from math import pi
from IPython.display import display, clear_output

# %% [markdown]
# Now import your `NeuralNetwork` regression class that uses `numpy` and has the `scg` optimizer available.

# %%
import neuralnetworksA4 as nn  # where you implement the NeuralNetwork class

# %%
class Robot():

    def __init__(self, link_lengths):
        self.n_links = len(link_lengths)
        self.record_angles = False
        self.angles = []
        self.link_lengths = np.array(link_lengths)
        self.joint_angles = np.zeros(self.n_links)
        self.points = [[10, 10] for _ in range(self.n_links + 1)]
        self.lim = sum(link_lengths)
        self.update_points()
        self.goal = None

    def set_goal(self, g):
        self.goal = g

    def dist_to_goal(self):
        return np.sqrt(np.sum((self.goal - self.end_effector)**2))
    
    def update_joints(self, joint_angles):
        self.joint_angles = joint_angles
        self.update_points()

    def add_to_joints(self, joint_angle_deltas):
        self.joint_angles += joint_angle_deltas
        too_high = self.joint_angles > 2 * pi
        self.joint_angles[too_high] = self.joint_angles[too_high] - 2 * pi
        too_low = self.joint_angles < 0
        self.joint_angles[too_low] = self.joint_angles[too_low] + 2 * pi
        if self.record_angles:
            self.angles.append(self.joint_angles * 180 / pi)
        self.update_points()

    def update_points(self):
        for i in range(1, self.n_links + 1):
            self.points[i][0] = (self.points[i - 1][0]
                                 + self.link_lengths[i - 1] * np.cos(np.sum(self.joint_angles[:i])))
            self.points[i][1] = (self.points[i - 1][1] +
                                 self.link_lengths[i - 1] * np.sin(np.sum(self.joint_angles[:i])))
        self.end_effector = np.array(self.points[self.n_links]).T

    def get_angles(self):
        return self.joint_angles
    

    def plot(self, style):
        for i in range(self.n_links + 1):
            if i is not self.n_links:
                plt.plot([self.points[i][0], self.points[i + 1][0]],
                         [self.points[i][1], self.points[i + 1][1]], style)
            plt.plot(self.points[i][0], self.points[i][1], 'k.')
        plt.axis('off')
        plt.axis('square')
        plt.xlim([-1, 21])
        plt.ylim([-1, 21])

    def animate(self, n_steps, Qnet=None, show_all_steps=False):
        fig = plt.figure(figsize=(8, 8))
        
        for i in range(n_steps):
            if not show_all_steps:
                fig.clf()
            plt.scatter(self.goal[0], self.goal[1], s=80)
            if Qnet:
                action, Qvalue = epsilon_greedy(self, Qnet, valid_actions, epsilon=0)
            else:
                action = [0.1] * self.n_links
            self.add_to_joints(action)
            style = 'b-' if show_all_steps and i+1 == n_steps else 'r-'
            self.plot(style)
            
            if not show_all_steps:
                clear_output(wait=True)
                display(fig)
            
        if not show_all_steps:
            clear_output(wait=True)

# %% [markdown]
# To use this class, first instantiate a robot by specifying the number of links and the lengths of each link as a list.  Imagine the end of the last link of the robot has a gripper. Set the goal location for the gripper by calling `robot.set_goal()`.
#
# Then you can animate the robot for some number of steps.

# %%
robot = Robot([4, 3])
robot.set_goal([4, 5])
robot.animate(100)

# %%
robot = Robot([4, 3])
robot.set_goal([4, 5])
robot.animate(100, show_all_steps=True)

# %% [markdown]
# # Reinforcement Learning Problem for Controlling the Robot

# %% [markdown]
# To define the reinforcement learning problem for controlling this robot, and trying to move the gripper as close to the goal as you can, we need to define the three main functions that define a reinforcement learning problem.  These are pretty easy with the functions available to us in the `Robot` class.  We will also need a function to represent the joint angles as sines and cosines.

# %%
def angles_to_sin_cos(angles):
    return np.hstack((np.sin(angles), np.cos(angles)))


def initial_state(robot):
    robot.update_joints(np.random.uniform(-2 * pi, 2 * pi, size=(robot.n_links)))
    angles = robot.get_angles()
    state = angles_to_sin_cos(angles)
    return state


def next_state(robot, action):
    robot.add_to_joints(action)
    angles = robot.get_angles()
    state = angles_to_sin_cos(angles)
    return state


def reinforcement(robot):
    '''Objective is to move gripper to the goal location as quickly as possible.'''
    dist_to_goal = robot.dist_to_goal()
    return dist_to_goal

# %%
angles_to_sin_cos([0, pi/4, pi/2, pi, -pi])
# Out:
# array([ 0.00000000e+00,  7.07106781e-01,  1.00000000e+00,  1.22464680e-16,
#        -1.22464680e-16,  1.00000000e+00,  7.07106781e-01,  6.12323400e-17,
#        -1.00000000e+00, -1.00000000e+00])

# %%
initial_state(robot)
# Out:
# array([ 0.42205002, -0.47565604, -0.90657255,  0.87963136])

# %%
next_state(robot, [-1, 1])
# Out:
# array([ 0.99088909,  0.48318621, -0.13468039,  0.87551761])

# %%
reinforcement(robot)
# Out:
# 11.948896084421387

# %% [markdown]
# Now we need our two workhorse functions, `epsilon_greedy` and `make_samples`.

# %%
def epsilon_greedy(robot, Qnet, valid_actions, epsilon):
    state = angles_to_sin_cos(robot.get_angles())
    
    if np.random.uniform() < epsilon:
        
        # Random Move
        actioni = np.random.randint(valid_actions.shape[0])
        action = valid_actions[actioni]
        
    else:
        # Greedy Move
        
        Qs = [Qnet.use(np.hstack((state, a)).reshape((1, -1))) for a in valid_actions]
        ai = np.argmin(Qs)
        action = valid_actions[ai]
        
    Q = Qnet.use(np.hstack((state, action)).reshape((1, -1)))
    
    return action, Q

# %%
def make_samples(robot, Qnet, initial_state_f, next_state_f, reinforcement_f,
                 valid_actions, n_samples, epsilon):

    X = np.zeros((n_samples, Qnet.n_inputs))
    R = np.zeros((n_samples, 1))
    Qn = np.zeros((n_samples, 1))

    state = initial_state_f(robot)
    state = next_state_f(robot, [0] * robot.n_links)  # 0 action for all joints
    action, _ = epsilon_greedy(robot, Qnet, valid_actions, epsilon)

    # Collect data from numSamples steps
    for step in range(n_samples):
        
        next_state = next_state_f(robot, action)
        r = reinforcement_f(robot)
        next_action, next_Q = epsilon_greedy(robot, Qnet, valid_actions, epsilon)
        
        X[step, :] = np.hstack((state, action))
        R[step, 0] = r
        Qn[step, 0] = next_Q
        
        # Advance one time step
        state, action = next_state, next_action

    return (X, R, Qn)

# %% [markdown]
# # Reinforcement Learning Training Algorithm

# %%
def setup_standardization(Qnet, Xmeans, Xstds, Tmeans, Tstds):
    Qnet.X_means = np.array(Xmeans)
    Qnet.X_stds = np.array(Xstds)
    Qnet.T_means = np.array(Tmeans)
    Qnet.T_stds = np.array(Tstds)

def train(robot, n_hiddens_list, valid_actions, n_trials, n_steps_per_trial, n_scg_iterations,
          final_epsilon, gamma=0.8):

    epsilon_decay = np.exp(np.log(final_epsilon) / (n_trials))  # to produce this final value

    n_inputs = robot.n_links * 2 + robot.n_links
    
    Qnet = nn.NeuralNetwork(n_inputs, n_hiddens_list, 1)

    means_state = [0] * robot.n_links * 2
    means_actions = [0] * robot.n_links
    stds_states = [0.5] * robot.n_links * 2
    stds_actions = [1.0] * robot.n_links
    setup_standardization(Qnet, means_state + means_actions, stds_states + stds_actions, [0], [1])

    epsilon = 1         # initial epsilon value
    epsilon_trace = []
    r_mean_trace = []
    r_trace = []
    learning_rate = 0.1
    for trial in range(n_trials):

        # Collect n_steps_per_trial samples
        
        X, R, Qn = make_samples(robot,Qnet, initial_state, next_state, reinforcement, valid_actions, n_steps_per_trial, epsilon)
    
        # Train Qnet on these samples for n_scg_iterations
        
        Qnet.train(X, R + gamma * Qn, n_epochs=n_scg_iterations,method='scg', learning_rate=learning_rate, verbose=False)
        
        # Update the three traces
        
        i = trial * n_steps_per_trial
        j = i + n_steps_per_trial
        epsilon_trace.append(epsilon)
        r_trace.extend(R)  

        r_mean_trace.append(np.mean(R))
        
        # Decay epsilon
        epsilon *= epsilon_decay
        
        if trial + 1 == n_trials or (trial + 1) % (n_trials // 10) == 0:
            print(f'Trial {trial+1}: Mean R {r_mean_trace[-1]:.2f}')
             
    return Qnet, r_mean_trace, r_trace, epsilon_trace

# %%
single_joint_actions = [-0.1, 0, 0.1]
valid_actions =  np.array(list(itertools.product(single_joint_actions, repeat=robot.n_links)))

# %%
robot = Robot([3., 3.])
robot.set_goal([5., 6.])

# %%
robot

# %%
n_hiddens_list = [50, 10]
n_trials = 200
n_steps_per_trial = 1000
n_scg_iterations = 4
final_epsilon = 0.01
gamma = 0.9

np.random.seed(42)
Qnet, r_mean_trace, r_trace, epsilon_trace = train(robot, n_hiddens_list, valid_actions, n_trials,
                                                   n_steps_per_trial, n_scg_iterations,
                                                   final_epsilon, gamma)
# Out:
# Trial 20: Mean R 7.26
# Trial 40: Mean R 6.15
# Trial 60: Mean R 5.40
# Trial 80: Mean R 2.30
# Trial 100: Mean R 1.53
# Trial 120: Mean R 0.99
# Trial 140: Mean R 2.33
# Trial 160: Mean R 0.85
# Trial 180: Mean R 1.08
# Trial 200: Mean R 3.46

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
plt.clf()
plt.subplot(3, 1, 1)
plt.plot(r_mean_trace)
plt.xlabel('Trial')
plt.ylabel('Mean R per Trial')

plt.subplot(3, 1, 2)
plt.plot(r_trace)
plt.xlabel('Step')
plt.ylabel('Value of $r_t$')

plt.subplot(3, 1, 3)
plt.plot(epsilon_trace)
plt.xlabel('Trial')
plt.ylabel('Epsilon');

# %%
import numpy as np
np.random.seed(1234)
initial_state(robot)
robot.animate(100, Qnet)

# %%
np.random.seed(1234)
initial_state(robot)
robot.animate(100, Qnet, show_all_steps=True)

# %%
np.random.seed(4444)
initial_state(robot)
robot.animate(100, Qnet, show_all_steps=True)

# %% [markdown]
# # Required Experiments
#
# Show the results and discuss what you see. Which parameter values result in the best performance during and at the end of training?
#
# ## Good parameter values
#
# Find values for parameters `n_hiddens_list`, `n_trials`, `n_steps_per_trial`, `n_scg_iterations`, and `gamma` that result in Mean R per Trial plot that shows fairly steady decrease to value close to 0.

# %%
n_hiddens_lists= [[50, 10],[100,50]]
n_trials = [100,200]
n_steps_per_trials = [1000,1500]
n_scg_iterations = [8,12]
final_epsilon = [0.01,0.001]
gamma = 0.9
least_r_trace = np.inf
results=[]
np.random.seed(42)
for n_hiddens_list in n_hiddens_lists:
    for n_trail in n_trials:
        for n_steps_per_trial in n_steps_per_trials:
            for n_scg_iteration in n_scg_iterations:
                for final in final_epsilon:
                    Qnet, r_mean_trace, r_trace, epsilon_trace = train(robot, n_hiddens_list, valid_actions, n_trail,
                                                                   n_steps_per_trial, n_scg_iteration,
                                                                   final, gamma)

                    results.append([Qnet,Qnet.all_weights,r_mean_trace,r_trace,epsilon_trace])
# Out:
# Trial 10: Mean R 6.91
# Trial 20: Mean R 6.90
# Trial 30: Mean R 7.16
# Trial 40: Mean R 5.52
# Trial 50: Mean R 3.76
# Trial 60: Mean R 2.75
# Trial 70: Mean R 1.45
# Trial 80: Mean R 3.16
# Trial 90: Mean R 2.96
# Trial 100: Mean R 3.16
# Trial 10: Mean R 6.68
# Trial 20: Mean R 4.04
# Trial 30: Mean R 0.82
# Trial 40: Mean R 2.49
# Trial 50: Mean R 3.66
# Trial 60: Mean R 9.03
# Trial 70: Mean R 1.83
# Trial 80: Mean R 1.60
# Trial 90: Mean R 1.47
# Trial 100: Mean R 0.89
# Trial 10: Mean R 6.19
# Trial 20: Mean R 3.04
# Trial 30: Mean R 1.16
# Trial 40: Mean R 1.57
# Trial 50: Mean R 1.14
# Trial 60: Mean R 1.00
# Trial 70: Mean R 0.97
# Trial 80: Mean R 0.62
# Trial 90: Mean R 0.49
# Trial 60: Mean R 0.71
# Trial 70: Mean R 0.91
# Trial 80: Mean R 0.77
# Trial 90: Mean R 0.61
# Trial 100: Mean R 0.80
# Trial 10: Mean R 7.07
# Trial 20: Mean R 8.04
# Trial 30: Mean R 6.03
# Trial 40: Mean R 0.92
# Trial 50: Mean R 0.98
# Trial 60: Mean R 0.81
# Trial 70: Mean R 0.86
# Trial 80: Mean R 1.04
# Trial 90: Mean R 1.01
# Trial 100: Mean R 0.63
# Trial 20: Mean R 7.45
# Trial 40: Mean R 3.61
# Trial 60: Mean R 1.59
# Trial 80: Mean R 1.07
# Trial 100: Mean R 1.32
# Trial 120: Mean R 0.80
# Trial 140: Mean R 0.60
# Trial 160: Mean R 0.72
# Trial 180: Mean R 0.81
# Trial 200: Mean R 0.66
# Trial 20: Mean R 7.71
# Trial 40: Mean R 1.74
# Trial 60: Mean R 1.01
# Trial 80: Mean R 0.99
# Trial 100: Mean R 1.04
# Trial 120: Mean R 0.84
# Trial 140: Mean R 0.87
# Trial 160: Mean R 0.74
# Trial 180: Mean R 1.69
# Trial 200: Mean R 0.76
# Trial 20: Mean R 4.66
# Trial 40: Mean R 0.78
# Trial 60: Mean R 0.78
# Trial 80: Mean R 0.79
# Trial 100: Mean R 0.72
# Trial 120: Mean R 1.01
# Trial 140: Mean R 1.02
# Trial 160: Mean R 0.72
# Trial 180: Mean R 0.83
# Trial 200: Mean R 0.77
# Trial 20: Mean R 7.81
# Trial 40: Mean R 1.49
# Trial 60: Mean R 0.93
# Trial 80: Mean R 0.78
# Trial 100: Mean R 0.66
# Trial 120: Mean R 7.57
# Trial 140: Mean R 0.64
# Trial 160: Mean R 0.67
# Trial 180: Mean R 0.74
# Trial 200: Mean R 0.62
# Trial 20: Mean R 6.70
# Trial 40: Mean R 4.79
# Trial 60: Mean R 3.68
# Trial 80: Mean R 0.95
# Trial 100: Mean R 0.51
# Trial 120: Mean R 0.68
# Trial 140: Mean R 0.49
# Trial 160: Mean R 0.54
# Trial 180: Mean R 0.56
# Trial 200: Mean R 0.58
# Trial 20: Mean R 8.34
# Trial 40: Mean R 4.23
# Trial 60: Mean R 0.82
# Trial 80: Mean R 0.83
# Trial 100: Mean R 0.98
# Trial 120: Mean R 0.86
# Trial 140: Mean R 0.82
# Trial 160: Mean R 0.87
# Trial 180: Mean R 0.76
# Trial 200: Mean R 0.88
# Trial 20: Mean R 7.03
# Trial 40: Mean R 0.74
# Trial 60: Mean R 0.73
# Trial 80: Mean R 0.85
# Trial 100: Mean R 0.67
# Trial 120: Mean R 0.61
# Trial 140: Mean R 0.61
# Trial 160: Mean R 0.57
# Trial 180: Mean R 0.48
# Trial 200: Mean R 0.46
# Trial 20: Mean R 6.98
# Trial 40: Mean R 1.09
# Trial 60: Mean R 0.84
# Trial 80: Mean R 0.81
# Trial 100: Mean R 0.61
# Trial 120: Mean R 0.49
# Trial 140: Mean R 0.58
# Trial 160: Mean R 0.52
# Trial 180: Mean R 0.59
# Trial 200: Mean R 0.68

# %%
import pandas as pd
df = pd.DataFrame(results,columns=['Qnet','Qnet.all_weights','r_mean_trace','r_trace','epsilon_trace'])

# %%
import warnings
warnings.filterwarnings('ignore')
df['final_r_mean'] = df.r_mean_trace.apply(lambda x: x[-1])

# %%
df
# Out:
#                                                  Qnet  \
# 0   NeuralNetwork(6, [50, 10], 1)\n Trained for 90...
# 1   NeuralNetwork(6, [50, 10], 1)\n Trained for 90...
# 2   NeuralNetwork(6, [50, 10], 1)\n Trained for 13...
# 3   NeuralNetwork(6, [50, 10], 1)\n Trained for 13...
# 4   NeuralNetwork(6, [50, 10], 1)\n Trained for 90...
# 5   NeuralNetwork(6, [50, 10], 1)\n Trained for 90...
# 6   NeuralNetwork(6, [50, 10], 1)\n Trained for 13...
# 7   NeuralNetwork(6, [50, 10], 1)\n Trained for 13...
# 8   NeuralNetwork(6, [50, 10], 1)\n Trained for 18...
# 9   NeuralNetwork(6, [50, 10], 1)\n Trained for 18...
# 10  NeuralNetwork(6, [50, 10], 1)\n Trained for 26...
# 11  NeuralNetwork(6, [50, 10], 1)\n Trained for 26...
# 12  NeuralNetwork(6, [50, 10], 1)\n Trained for 18...
# 13  NeuralNetwork(6, [50, 10], 1)\n Trained for 18...
# 14  NeuralNetwork(6, [50, 10], 1)\n Trained for 26...
# 15  NeuralNetwork(6, [50, 10], 1)\n Trained for 26...
# 16  NeuralNetwork(6, [100, 50], 1)\n Trained for 9...
# 17  NeuralNetwork(6, [100, 50], 1)\n Trained for 9...
# 18  NeuralNetwork(6, [100, 50], 1)\n Trained for 1...
# 19  NeuralNetwork(6, [100, 50], 1)\n Trained for 1...
# 20  NeuralNetwork(6, [100, 50], 1)\n Trained for 9...
# 21  NeuralNetwork(6, [100, 50], 1)\n Trained for 9...
# 22  NeuralNetwork(6, [100, 50], 1)\n Trained for 1...
# 23  NeuralNetwork(6, [100, 50], 1)\n Trained for 1...
# 24  NeuralNetwork(6, [100, 50], 1)\n Trained for 1...
# 25  NeuralNetwork(6, [100, 50], 1)\n Trained for 1...
# 26  NeuralNetwork(6, [100, 50], 1)\n Trained for 2...
# 27  NeuralNetwork(6, [100, 50], 1)\n Trained for 2...
# 28  NeuralNetwork(6, [100, 50], 1)\n Trained for 1...
# 29  NeuralNetwork(6, [100, 50], 1)\n Trained for 1...
# 30  NeuralNetwork(6, [100, 50], 1)\n Trained for 2...
# 31  NeuralNetwork(6, [100, 50], 1)\n Trained for 2...
#
#                                      Qnet.all_weights  \
# 0   [-0.22486277241723, 0.993497654718559, 0.31031...
# 1   [0.6449919356777601, -0.10079749502133112, 0.0...
# 2   [0.027417811549116426, 0.5196497609289141, -0....
# 3   [-0.12189521171333634, 0.4757153956069464, -0....
# 4   [0.07842537101983056, 0.8054108429037597, 0.04...
# 5   [0.5136145243258098, 0.2139908557608267, -0.35...
# 6   [0.3509632470305588, 0.11702692810663862, -0.0...
# 7   [-0.23976428814201597, 0.25428623291953817, 0....
# 8   [-0.1563840587314724, 0.11783258186069234, 0.3...
# 9   [-0.1573075183058404, 0.5450280675492956, 0.19...
# 10  [-0.45516285479977514, 0.3094991686933519, -0....
# 11  [0.001926872104527206, 0.12228674967148002, -0...
# 12  [0.32726860656775536, -0.043496714778824226, -...
# 13  [0.006612032732889732, 0.38688317486551066, 0....
# 14  [-0.9248271736186552, 0.7380741620277399, -1.1...
# 15  [0.4009147989461165, 0.6027985667264175, 0.215...
# 16  [0.172145926712778, -0.1386172468220165, -0.16...
# 17  [0.2984532378554587, 0.4473723082441115, -0.45...
# 18  [0.004753624235946591, 0.6172106176892916, -0....
# 8   [[11.808285450030521], [11.923666375683531], [...
# 9   [[6.522183977192399], [6.027653700487279], [6....
# 10  [[6.246680524335908], [6.388499698315298], [6....
# 11  [[12.200130758368813], [12.166146948152189], [...
# 12  [[10.7995636040145], [10.692565834532013], [10...
# 13  [[6.4085888168079705], [6.219979916537294], [6...
# 14  [[4.52161476829443], [4.2311638736140385], [4....
# 15  [[0.6755872480503186], [0.6067699136272204], [...
# 16  [[5.410362143645074], [5.735467676672117], [6....
# 17  [[12.278698193424498], [12.196611815512805], [...
# 18  [[4.50799021734532], [4.752294871230875], [4.5...
# 19  [[7.042502941699434], [6.9202261016848405], [6...
# 20  [[7.6597320570304825], [7.3737178966902714], [...
# 21  [[2.1261167552177977], [1.305266431153603], [1...
# 22  [[4.332398493603639], [4.571627329856378], [4....
# 23  [[4.777974409954185], [5.065389620378356], [4....
# 24  [[10.567730812626422], [10.993392186036788], [...
# 25  [[8.471312734185915], [8.584889648966588], [8....
# 26  [[6.114882067072786], [6.328953650517634], [6....
# 27  [[7.418783447771459], [7.589541967025599], [7....
# 28  [[8.282167728453187], [7.9855415679832795], [7...
# 29  [[7.068369700782945], [7.329876166940612], [7....
# 30  [[1.4698088258834594], [1.4698088258834594], [...
# 31  [[6.959839331015006], [7.279158512460174], [7....
#
#                                         epsilon_trace  final_r_mean
# 0   [1, 0.954992586021436, 0.9120108393559099, 0.8...      3.155788
# 1   [1, 0.933254300796991, 0.8709635899560806, 0.8...      0.890631
# 2   [1, 0.954992586021436, 0.9120108393559099, 0.8...      0.647547
# 3   [1, 0.933254300796991, 0.8709635899560806, 0.8...      1.256321
# 4   [1, 0.954992586021436, 0.9120108393559099, 0.8...      0.775351
# 5   [1, 0.933254300796991, 0.8709635899560806, 0.8...      3.354432
# 6   [1, 0.954992586021436, 0.9120108393559099, 0.8...      0.593432
# 7   [1, 0.933254300796991, 0.8709635899560806, 0.8...      1.676122
# 8   [1, 0.9772372209558107, 0.9549925860214359, 0....      0.608491
# 9   [1, 0.9660508789898133, 0.933254300796991, 0.9...      1.281272
# 10  [1, 0.9772372209558107, 0.9549925860214359, 0....      0.837869
# 11  [1, 0.9660508789898133, 0.933254300796991, 0.9...      0.462641
# 12  [1, 0.9772372209558107, 0.9549925860214359, 0....      0.525742
# 13  [1, 0.9660508789898133, 0.933254300796991, 0.9...      0.990117
# 14  [1, 0.9772372209558107, 0.9549925860214359, 0....      0.596608
# 15  [1, 0.9660508789898133, 0.933254300796991, 0.9...      0.783933
# 16  [1, 0.954992586021436, 0.9120108393559099, 0.8...      2.137091
# 17  [1, 0.933254300796991, 0.8709635899560806, 0.8...      3.750225
# 18  [1, 0.954992586021436, 0.9120108393559099, 0.8...      0.495554
# 19  [1, 0.933254300796991, 0.8709635899560806, 0.8...      3.097064
# 20  [1, 0.954992586021436, 0.9120108393559099, 0.8...      0.548551
# 21  [1, 0.933254300796991, 0.8709635899560806, 0.8...      2.208413
# 22  [1, 0.954992586021436, 0.9120108393559099, 0.8...      0.800105
# 23  [1, 0.933254300796991, 0.8709635899560806, 0.8...      0.629033
# 24  [1, 0.9772372209558107, 0.9549925860214359, 0....      0.658966
# 25  [1, 0.9660508789898133, 0.933254300796991, 0.9...      0.757292
# 26  [1, 0.9772372209558107, 0.9549925860214359, 0....      0.767852
# 27  [1, 0.9660508789898133, 0.933254300796991, 0.9...      0.620148
# 28  [1, 0.9772372209558107, 0.9549925860214359, 0....      0.581617
# 29  [1, 0.9660508789898133, 0.933254300796991, 0.9...      0.876495
# 30  [1, 0.9772372209558107, 0.9549925860214359, 0....      0.460311
# 31  [1, 0.9660508789898133, 0.933254300796991, 0.9...      0.682979

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
plt.clf()
plt.subplot(3, 1, 1)
plt.plot(df['r_mean_trace'][5])
plt.xlabel('Trial')
plt.ylabel('Mean R per Trial')

plt.subplot(3, 1, 2)
plt.plot(df['r_trace'][5])
plt.xlabel('Step')
plt.ylabel('Value of $r_t$')

plt.subplot(3, 1, 3)
plt.plot(df['epsilon_trace'][5])
plt.xlabel('Trial')
plt.ylabel('Epsilon');

# %%
import numpy as np
np.random.seed(1234)
initial_state(robot)
robot.animate(100,df['Qnet'][5])

# %%
np.random.seed(1234)
initial_state(robot)
robot.animate(100, df['Qnet'][5], show_all_steps=True)

# %%
np.random.seed(4444)
initial_state(robot)
robot.animate(100, df['Qnet'][5], show_all_steps=True)

# %% [markdown]
# ## Create robot with four links of lengths, 4, 3, 3,  and 2.
#
# Again, find good values for the parameters.

# %%
robot_4link = Robot([4,3,3,2])
robot_4link.set_goal([4,4])
robot_4link.animate(100)

# %%
robot_4link = Robot([4, 3,3,2])
robot_4link.set_goal([4, 4])
robot_4link.animate(100, show_all_steps=True)

# %%
initial_state(robot_4link)
# Out:
# array([ 0.07833086,  0.61839774,  0.06483287, -0.35836233, -0.99692742,
#        -0.78586528,  0.99789614,  0.93358258])

# %%
next_state(robot_4link, [-1, 1,1,-1])
# Out:
# array([ 0.88120784, -0.3271611 ,  0.87473   , -0.97920665, -0.47272904,
#        -0.94496858,  0.4846106 ,  0.20286532])

# %%
reinforcement(robot_4link)
# Out:
# 12.173785436752619

# %%
single_joint_actions = [-0.1, 0, 0.1]
valid_actions =  np.array(list(itertools.product(single_joint_actions, repeat=robot_4link.n_links)))

# %%
robot_4link = Robot([4.,3.,3.,2.])
robot_4link.set_goal([4., 4.])

# %%
n_hiddens_list = [50, 10]
n_trials = 200
n_steps_per_trial = 1000
n_scg_iterations = 4
final_epsilon = 0.01
gamma = 0.9

np.random.seed(42)
Qnet, r_mean_trace, r_trace, epsilon_trace = train(robot_4link, n_hiddens_list, valid_actions, n_trials,
                                                   n_steps_per_trial, n_scg_iterations,
                                                   final_epsilon, gamma)
# Out:
# Trial 20: Mean R 8.42
# Trial 40: Mean R 9.01
# Trial 60: Mean R 7.44
# Trial 80: Mean R 8.98
# Trial 100: Mean R 9.85
# Trial 120: Mean R 7.05
# Trial 140: Mean R 5.63
# Trial 160: Mean R 2.19
# Trial 180: Mean R 2.99
# Trial 200: Mean R 2.23

# %%
n_hiddens_lists= [[50, 10],[200,50]]
n_trials = 300
n_steps_per_trials = [1000]
n_scg_iterations = 10
final_epsilon = 0.001
gamma = [0.9]
least_r_trace = np.inf
results1=[]
np.random.seed(42)
for n_hiddens_list in n_hiddens_lists:
    for n_steps_per_trial in n_steps_per_trials:
        for g in gamma:

            Qnet, r_mean_trace, r_trace, epsilon_trace = train(robot_4link, n_hiddens_list, valid_actions, n_trials,
                                                           n_steps_per_trial, n_scg_iterations,
                                                           final_epsilon, g)

            results1.append([Qnet,Qnet.all_weights,r_mean_trace,r_trace,epsilon_trace])
# Out:
# Trial 30: Mean R 5.60
# Trial 60: Mean R 1.55
# Trial 90: Mean R 4.19
# Trial 120: Mean R 2.61
# Trial 150: Mean R 1.10
# Trial 180: Mean R 0.79
# Trial 210: Mean R 0.85
# Trial 240: Mean R 0.78
# Trial 270: Mean R 1.18
# Trial 300: Mean R 0.37
# Trial 30: Mean R 5.28
# Trial 60: Mean R 4.56
# Trial 90: Mean R 1.76
# Trial 120: Mean R 1.25
# Trial 150: Mean R 1.35
# Trial 180: Mean R 1.55
# Trial 210: Mean R 1.63
# Trial 240: Mean R 1.39
# Trial 270: Mean R 1.26
# Trial 300: Mean R 1.36

# %%
import pandas as pd
df1 = pd.DataFrame(results1, columns=['Qnet','Qnet.all_weights','r_mean_trace','r_trace','epsilon_trace'])
df1['final_r_mean'] = df1.r_mean_trace.apply(lambda x: x[-1])
df1
# Out:
#                                                 Qnet  \
# 0  NeuralNetwork(12, [50, 10], 1)\n Trained for 3...
# 1  NeuralNetwork(12, [200, 50], 1)\n Trained for ...
#
#                                     Qnet.all_weights  \
# 0  [0.03776250205318979, 0.3990415985441455, 0.20...
# 1  [-0.5283430843203712, 0.1703276046875251, -0.2...
#
#                                         r_mean_trace  \
# 0  [10.423727823479679, 8.634522162333132, 6.9296...
# 1  [6.541588808004445, 12.145536618980891, 9.1741...
#
#                                              r_trace  \
# 0  [[13.061958216954054], [13.800874312222884], [...
# 1  [[14.453172953033043], [14.269524957290763], [...
#
#                                        epsilon_trace  final_r_mean
# 0  [1, 0.9772372209558107, 0.9549925860214359, 0....      0.368747
# 1  [1, 0.9772372209558107, 0.9549925860214359, 0....      1.358525

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
plt.clf()
plt.subplot(3, 1, 1)
plt.plot(df1['r_mean_trace'][0])
plt.xlabel('Trial')
plt.ylabel('Mean R per Trial')

plt.subplot(3, 1, 2)
plt.plot(df1['r_trace'][0])
plt.xlabel('Step')
plt.ylabel('Value of $r_t$')

plt.subplot(3, 1, 3)
plt.plot(df1['epsilon_trace'][0])
plt.xlabel('Trial')
plt.ylabel('Epsilon');

# %%
import numpy as np
np.random.seed(1234)
initial_state(robot)
robot_4link.animate(100,df1['Qnet'][0])

# %%
np.random.seed(4444)
initial_state(robot)
robot_4link.animate(100, df1['Qnet'][0], show_all_steps=True)

# %% [markdown]
# ## Increase number of valid actions
#
# We have been using just three different actions for each joint, `[-0.1, 0, 0.1]`.  Allow more precision in the control by changing this list of valid actions for each joint to `[-0.1, -0.05, 0, 0.05, 0.1]`.
#
# As before, find good values for the parameters.

# %%
single_joint_actions = [-0.1, -0.05, 0, 0.05, 0.1]
valid_actions =  np.array(list(itertools.product(single_joint_actions, repeat=robot.n_links)))

# %%
robot = Robot([3., 3.])
robot.set_goal([5., 6.])

# %%
n_hiddens_list = [100, 10]
n_trials = 200
n_steps_per_trial = 1000
n_scg_iterations = 6
final_epsilon = 0.01
gamma = 0.9

np.random.seed(42)
Qnet, r_mean_trace, r_trace, epsilon_trace = train(robot, n_hiddens_list, valid_actions, n_trials,
                                                   n_steps_per_trial, n_scg_iterations,
                                                   final_epsilon, gamma)
# Out:
# Trial 20: Mean R 6.72
# Trial 40: Mean R 2.53
# Trial 60: Mean R 2.30
# Trial 80: Mean R 2.06
# Trial 100: Mean R 1.20
# Trial 120: Mean R 1.01
# Trial 140: Mean R 0.78
# Trial 160: Mean R 0.71
# Trial 180: Mean R 0.57
# Trial 200: Mean R 4.76

# %%
n_hiddens_lists= [[50, 10],[80,50]]
n_trials = [200,300]
n_steps_per_trials = 1000
n_scg_iterations = 10
final_epsilon = 0.001
gamma = [0.9,0.7]
least_r_trace = np.inf
results2=[]
np.random.seed(42)
for n_hiddens_list in n_hiddens_lists:
    for n_trial in n_trials:
        for g in gamma:

            Qnet, r_mean_trace, r_trace, epsilon_trace = train(robot, n_hiddens_list, valid_actions, n_trial,
                                                           n_steps_per_trials, n_scg_iterations,
                                                           final_epsilon, g)

            

            results2.append([Qnet,Qnet.all_weights,r_mean_trace,r_trace,epsilon_trace])
# Out:
# Trial 20: Mean R 6.83
# Trial 40: Mean R 0.94
# Trial 60: Mean R 2.92
# Trial 80: Mean R 0.97
# Trial 100: Mean R 0.68
# Trial 120: Mean R 0.67
# Trial 140: Mean R 0.75
# Trial 160: Mean R 0.78
# Trial 180: Mean R 0.90
# Trial 200: Mean R 0.74
# Trial 20: Mean R 3.65
# Trial 40: Mean R 4.14
# Trial 60: Mean R 2.37
# Trial 80: Mean R 2.50
# Trial 100: Mean R 1.12
# Trial 120: Mean R 0.53
# Trial 140: Mean R 0.57
# Trial 160: Mean R 0.50
# Trial 180: Mean R 0.48
# Trial 200: Mean R 0.65
# Trial 30: Mean R 7.56
# Trial 60: Mean R 0.89
# Trial 90: Mean R 0.94
# Trial 120: Mean R 3.61
# Trial 150: Mean R 0.71
# Trial 180: Mean R 0.79
# Trial 210: Mean R 0.63
# Trial 240: Mean R 0.62
# Trial 270: Mean R 0.83
# Trial 300: Mean R 0.85
# Trial 30: Mean R 1.22
# Trial 60: Mean R 1.16
# Trial 90: Mean R 0.55
# Trial 120: Mean R 0.64
# Trial 150: Mean R 0.66
# Trial 180: Mean R 0.63
# Trial 210: Mean R 0.76
# Trial 240: Mean R 0.49
# Trial 270: Mean R 0.60
# Trial 300: Mean R 0.47
# Trial 20: Mean R 6.57
# Trial 40: Mean R 3.50
# Trial 60: Mean R 0.67
# Trial 80: Mean R 0.70
# Trial 100: Mean R 0.93
# Trial 120: Mean R 0.80
# Trial 140: Mean R 0.81
# Trial 160: Mean R 0.84
# Trial 180: Mean R 0.87
# Trial 200: Mean R 0.99
# Trial 20: Mean R 2.17
# Trial 40: Mean R 2.56
# Trial 60: Mean R 2.40
# Trial 80: Mean R 0.83
# Trial 100: Mean R 0.86
# Trial 120: Mean R 0.89
# Trial 140: Mean R 0.68
# Trial 160: Mean R 0.54
# Trial 180: Mean R 0.79
# Trial 200: Mean R 0.58
# Trial 30: Mean R 6.49
# Trial 60: Mean R 0.98
# Trial 90: Mean R 0.86
# Trial 120: Mean R 0.70
# Trial 150: Mean R 0.73
# Trial 180: Mean R 0.84
# Trial 210: Mean R 0.65
# Trial 240: Mean R 0.61
# Trial 270: Mean R 0.63
# Trial 300: Mean R 0.62
# Trial 30: Mean R 4.39
# Trial 60: Mean R 0.79
# Trial 90: Mean R 0.76
# Trial 120: Mean R 0.53
# Trial 150: Mean R 0.48
# Trial 180: Mean R 0.51
# Trial 210: Mean R 0.46
# Trial 240: Mean R 0.51
# Trial 270: Mean R 0.60
# Trial 300: Mean R 0.77

# %%
import pandas as pd
df2 = pd.DataFrame(results2,columns=['Qnet','Qnet.all_weights','r_mean_trace','r_trace','epsilon_trace'])
df2['final_r_mean'] = df2.r_mean_trace.apply(lambda x: x[-1])
df2
# Out:
#                                                 Qnet  \
# 0  NeuralNetwork(6, [50, 10], 1)\n Trained for 22...
# 1  NeuralNetwork(6, [50, 10], 1)\n Trained for 22...
# 2  NeuralNetwork(6, [50, 10], 1)\n Trained for 33...
# 3  NeuralNetwork(6, [50, 10], 1)\n Trained for 33...
# 4  NeuralNetwork(6, [80, 50], 1)\n Trained for 22...
# 5  NeuralNetwork(6, [80, 50], 1)\n Trained for 22...
# 6  NeuralNetwork(6, [80, 50], 1)\n Trained for 33...
# 7  NeuralNetwork(6, [80, 50], 1)\n Trained for 33...
#
#                                     Qnet.all_weights  \
# 0  [-0.36810804214871284, 0.377944499865505, 0.23...
# 1  [-0.6951938019072097, -0.6493499970517187, -0....
# 2  [0.4963609718512054, -0.6747330287704842, 0.52...
# 3  [-0.10161688436830721, 0.5712942042448191, -0....
# 4  [0.0616703259399539, 0.08568074068540543, 0.37...
# 5  [0.1322271724536359, -0.31402921164068737, 0.3...
# 6  [-0.061224871722542124, 0.46693889662194027, 0...
# 7  [-0.36779205505124546, 0.38167319195984695, 0....
#
#                                         r_mean_trace  \
# 0  [6.709707525390434, 8.379202037556688, 5.90889...
# 1  [9.036179741190912, 6.940532212579104, 7.01824...
# 2  [7.1159693560537285, 6.289177893115401, 8.5819...
# 3  [7.343177544876329, 6.4263124067031425, 6.6764...
# 4  [7.845860233606442, 8.681151884756003, 6.52109...
# 5  [5.432620284315135, 9.44227813013696, 7.399859...
# 6  [9.03552920059848, 4.948040654002094, 5.988800...
# 7  [10.462726649284384, 4.697461158176029, 7.3656...
#
#                                              r_trace  \
# 0  [[1.9728354660861107], [1.6753641631997989], [...
# 1  [[9.388576316714161], [9.669282982568724], [9....
# 2  [[4.786949986905316], [4.695348434294013], [4....
# 3  [[5.989096783609166], [6.148179237588726], [6....
# 4  [[9.736299992976274], [9.521268219631077], [9....
# 5  [[6.300900892455663], [6.357110431829204], [6....
# 6  [[4.060402806653857], [4.449002640335886], [4....
# 7  [[11.768057885355672], [11.618297238996442], [...
#
#                                        epsilon_trace  final_r_mean
# 0  [1, 0.9660508789898133, 0.933254300796991, 0.9...      0.735237
# 1  [1, 0.9660508789898133, 0.933254300796991, 0.9...      0.651829
# 2  [1, 0.9772372209558107, 0.9549925860214359, 0....      0.847002
# 3  [1, 0.9772372209558107, 0.9549925860214359, 0....      0.471093
# 4  [1, 0.9660508789898133, 0.933254300796991, 0.9...      0.985315
# 5  [1, 0.9660508789898133, 0.933254300796991, 0.9...      0.575573
# 6  [1, 0.9772372209558107, 0.9549925860214359, 0....      0.624948
# 7  [1, 0.9772372209558107, 0.9549925860214359, 0....      0.774341

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
plt.clf()
plt.subplot(3, 1, 1)
plt.plot(df2['r_mean_trace'][5])
plt.xlabel('Trial')
plt.ylabel('Mean R per Trial')

plt.subplot(3, 1, 2)
plt.plot(df2['r_trace'][5])
plt.xlabel('Step')
plt.ylabel('Value of $r_t$')

plt.subplot(3, 1, 3)
plt.plot(df2['epsilon_trace'][5])
plt.xlabel('Trial')
plt.ylabel('Epsilon');

# %%
import numpy as np
np.random.seed(1234)
initial_state(robot)
robot.animate(100,df2['Qnet'][5])

# %%
np.random.seed(4444)
initial_state(robot)
robot.animate(100, df2['Qnet'][5], show_all_steps=True)

# %% [markdown]
# # Extra Credit
#
# Earn 1 extra credit point by done one of the following two options, or do both of them for 2 extra credit points
#
# 1. Modify the code to be in the modular form discussed in class.  Your `Robot` class should extend `Environment` and define class `Qnet` that extends `Agent`.  Demonstrate that this new code works.
# 2. As discussed in class for the marble control, make modifications to allow a variable goal.  Add the goal coordinates to the state input to the Qnet.  Demonstrate success by plotting `r_mean_trace` for four different, fixed, goals.
